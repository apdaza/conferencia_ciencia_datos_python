# %% [markdown]
# Importamos las librerias
#
# en caso de no tenerlas instaladas ejecutar lo siguiente:
# > pip install pandas
# > pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Cargamos la data

# %%
df = pd.read_csv('us_states_covid19_daily.csv')
df.head()
# Out:
#        date state  positive  probableCases   negative  pending  \
# 0  20201206    AK   35720.0            NaN  1042056.0      NaN
# 1  20201206    AL  269877.0        45962.0  1421126.0      NaN
# 2  20201206    AR  170924.0        22753.0  1614979.0      NaN
# 3  20201206    AS       0.0            NaN     2140.0      NaN
# 4  20201206    AZ  364276.0        12590.0  2018813.0      NaN
#
#   totalTestResultsSource  totalTestResults  hospitalizedCurrently  \
# 0        totalTestsViral         1077776.0                  164.0
# 1  totalTestsPeopleViral         1645041.0                 1927.0
# 2        totalTestsViral         1763150.0                 1076.0
# 3        totalTestsViral            2140.0                    NaN
# 4  totalTestsPeopleViral         2370499.0                 2977.0
#
#    hospitalizedCumulative  ...   posNeg  deathIncrease  hospitalizedIncrease  \
# 0                   799.0  ...  1077776              0                     0
# ...

# %%
df.shape
# Out:
# (15633, 55)

# %%
df_hi = df[df.positive >= 500000]
df_hi.head()
# Out:
#         date state   positive  probableCases    negative  pending  \
# 5   20201206    CA  1341700.0            NaN  23853346.0      NaN
# 10  20201206    FL  1040727.0       100964.0   6505237.0   5892.0
# 16  20201206    IL   787573.0         6259.0  10313641.0      NaN
# 37  20201206    NY   705827.0            NaN  19888867.0      NaN
# 47  20201206    TX  1249323.0            NaN  10111653.0      NaN
#
#       totalTestResultsSource  totalTestResults  hospitalizedCurrently  \
# 5            totalTestsViral        25195046.0                10624.0
# 10  totalTestEncountersViral        13083521.0                 4400.0
# 16                    posNeg        11101214.0                 5160.0
# 37  totalTestEncountersViral        20594694.0                 4442.0
# 47                    posNeg        11360976.0                 8681.0
#
#     hospitalizedCumulative  ...    posNeg  deathIncrease  \
# 5                      NaN  ...  25195046             85
# ...

# %%
df_hi.shape
# Out:
# (436, 55)

# %%
plt.figure(figsize=(8, 9))
plt.bar(df_hi['state'], df_hi['positive'], color='blue')
plt.title('Estados con los mayores casos de COVID-19')
plt.xlabel('Estados')
plt.ylabel('Casos en millones')
# Out:
# Text(0, 0.5, 'Casos en millones')

# %%
df_FL = df[df.state == 'FL']
df_FL = df_FL.sort_values(by='date')
df_FL.head()
# Out:
#            date state  positive  probableCases  negative  pending  \
# 15616  20200129    FL       0.0            NaN       NaN      NaN
# 15613  20200130    FL       0.0            NaN       NaN      NaN
# 15610  20200131    FL       0.0            NaN       NaN      NaN
# 15607  20200201    FL       0.0            NaN       NaN      NaN
# 15604  20200202    FL       0.0            NaN       NaN      NaN
#
#          totalTestResultsSource  totalTestResults  hospitalizedCurrently  \
# 15616  totalTestEncountersViral               1.0                    NaN
# 15613  totalTestEncountersViral               1.0                    NaN
# 15610  totalTestEncountersViral               4.0                    NaN
# 15607  totalTestEncountersViral               4.0                    NaN
# 15604  totalTestEncountersViral               4.0                    NaN
#
#        hospitalizedCumulative  ...  posNeg  deathIncrease  \
# 15616                     NaN  ...       0              0
# ...

# %%
df_CA = df[df.state == 'CA']
df_CA = df_CA.sort_values(by='date')
df_CA.head()
# Out:
#            date state  positive  probableCases  negative  pending  \
# 15425  20200304    CA      53.0            NaN     462.0      NaN
# 15395  20200305    CA      53.0            NaN     462.0      NaN
# 15358  20200306    CA      60.0            NaN     462.0      NaN
# 15308  20200307    CA      69.0            NaN     462.0      NaN
# 15257  20200308    CA      88.0            NaN     462.0      NaN
#
#       totalTestResultsSource  totalTestResults  hospitalizedCurrently  \
# 15425        totalTestsViral             515.0                    NaN
# 15395        totalTestsViral             515.0                    NaN
# 15358        totalTestsViral             522.0                    NaN
# 15308        totalTestsViral             531.0                    NaN
# 15257        totalTestsViral             550.0                    NaN
#
#        hospitalizedCumulative  ...  posNeg  deathIncrease  \
# 15425                     NaN  ...     515              0
# ...

# %%
df_TX = df[df.state == 'TX']
df_TX = df_TX.sort_values(by='date')
df_TX.head()
# Out:
#            date state  positive  probableCases  negative  pending  \
# 15442  20200304    TX       1.0            NaN       NaN      NaN
# 15418  20200305    TX       1.0            NaN       NaN      NaN
# 15387  20200306    TX       5.0            NaN       NaN      NaN
# 15347  20200307    TX       8.0            NaN       NaN      NaN
# 15296  20200308    TX       8.0            NaN       NaN      NaN
#
#       totalTestResultsSource  totalTestResults  hospitalizedCurrently  \
# 15442                 posNeg               1.0                    NaN
# 15418                 posNeg               1.0                    NaN
# 15387                 posNeg               5.0                    NaN
# 15347                 posNeg               8.0                    NaN
# 15296                 posNeg               8.0                    NaN
#
#        hospitalizedCumulative  ...  posNeg  deathIncrease  \
# 15442                     NaN  ...       1              0
# ...

# %%
plt.plot(df_FL['date'], df_FL['positive'], color="red")
plt.title('Casos positivos en Florida')
plt.ylabel('Número de casos')
plt.xlabel('Desde 03-04-2020 al 12-06-2020')
plt.xticks([])
plt.show()

# %%
plt.plot(df_FL['date'], df_FL['death'], color="red")
plt.title('Muertes en Florida')
plt.ylabel('Número de casos')
plt.xlabel('Desde 03-04-2020 al 12-06-2020')
plt.xticks([])
plt.show()

# %%
plt.plot(df_FL['date'], df_FL['positive'], color="red")
plt.plot(df_FL['date'], df_FL['death'], color="black")
plt.title('Casos positivos y muertes en Florida')
plt.ylabel('Número de casos')
plt.xlabel('Desde 03-04-2020 al 12-06-2020')
plt.xticks([])
plt.show()

# %%
df_NY = df[df.state == 'NY']
df_NY = df_NY.sort_values(by='date')
df_NY.head()
# Out:
#            date state  positive  probableCases  negative  pending  \
# 15467  20200302    NY       0.0            NaN       NaN      NaN
# 15454  20200303    NY       1.0            NaN       0.0      NaN
# 15438  20200304    NY       1.0            NaN       9.0     24.0
# 15412  20200305    NY       3.0            NaN      27.0     24.0
# 15380  20200306    NY      25.0            NaN      97.0    236.0
#
#          totalTestResultsSource  totalTestResults  hospitalizedCurrently  \
# 15467  totalTestEncountersViral               0.0                    NaN
# 15454  totalTestEncountersViral               1.0                    NaN
# 15438  totalTestEncountersViral              10.0                    NaN
# 15412  totalTestEncountersViral              30.0                    NaN
# 15380  totalTestEncountersViral             122.0                    NaN
#
#        hospitalizedCumulative  ...  posNeg  deathIncrease  \
# 15467                     NaN  ...       0              0
# ...

# %%
plt.plot(df_FL['date'], df_FL['positive'], color="red", label='FL')
plt.plot(df_CA['date'], df_CA['positive'], color="blue", label='CA')
plt.plot(df_TX['date'], df_TX['positive'], color="green", label="TX")
plt.plot(df_NY['date'], df_NY['positive'], color="black", label="NY")
plt.title('Casos positivos')
plt.ylabel('Número de casos')
plt.xlabel('Desde 03-04-2020 al 12-06-2020')
plt.legend()
plt.xticks([])
plt.show()

# %%
plt.plot(df_FL['date'], df_FL['death'], color="red", label='FL')
plt.plot(df_CA['date'], df_CA['death'], color="blue", label='CA')
plt.plot(df_TX['date'], df_TX['death'], color="green", label="TX")
plt.plot(df_NY['date'], df_NY['death'], color="black", label="NY")
plt.title('Muertes por COVID')
plt.ylabel('Número de casos')
plt.xlabel('Desde 03-04-2020 al 12-06-2020')
plt.legend()
plt.xticks([])
plt.show()
